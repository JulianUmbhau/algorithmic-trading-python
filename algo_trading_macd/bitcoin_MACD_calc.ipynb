# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv("./data.csv", )



df = df.set_index(pd.DatetimeIndex(df["Unix.Timestamp"].values))

# %%
df
# Out:
#                      Unnamed: 0       Unix.Timestamp     Close
# 2021-02-28 01:02:00           1  2021-02-28 01:02:00  45857.03
# 2021-02-28 01:01:00           2  2021-02-28 01:01:00  45833.60
# 2021-02-28 01:00:00           3  2021-02-28 01:00:00  45945.21
# 2021-02-28 00:59:00           4  2021-02-28 00:59:00  46209.62
# 2021-02-28 00:58:00           5  2021-02-28 00:58:00  46115.76
# ...                         ...                  ...       ...
# 2020-01-01 01:04:00      584633  2020-01-01 01:04:00   7163.00
# 2020-01-01 01:03:00      584634  2020-01-01 01:03:00   7163.60
# 2020-01-01 01:02:00      584635  2020-01-01 01:02:00   7163.00
# 2020-01-01 01:01:00      584636  2020-01-01 01:01:00   7163.30
# 2020-01-01 01:00:00      584637  2020-01-01 01:00:00   7163.30
#
# [584637 rows x 3 columns]

# %%
plt.figure(figsize=(12.2, 4.5))
plt.plot(df["Close"], label = "Close")
plt.xticks(rotation=45)
plt.title("Close Price History")
plt.xlabel("Date")
plt.ylabel("Price USD")
plt.show()

# %%
#calculate macd
ShortEMA = df.Close.ewm(span=12, adjust=False).mean()

LongEMA = df.Close.ewm(span=26, adjust=False).mean()

MACD = ShortEMA - LongEMA

signal = MACD.ewm(span=9, adjust=False)

# %%
plt.figure(figsize=(12.2,4.5))
plt.plot(df.index, MACD, label=)
